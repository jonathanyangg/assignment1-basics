# %%
import torch

# %%
print(list("A".encode("utf-8")))
# Out:
# [65]

# %%
import regex as re

def train_bpe(input_path: str, vocab_size: int, special_tokens: list[str]) -> tuple[dict[int, bytes],list[tuple[bytes, bytes]]]:
    
    #config
    if vocab_size < 256:
        return 1
    num_special_tokens = len(special_tokens)
    num_merges = vocab_size - 256 - num_special_tokens

    vocab = {i:bytes([i]) for i in range(256)}
    for i in range(len(special_tokens)):
        vocab[256+i] = special_tokens[i].encode("utf-8")

    with open(input_path, "r", encoding="utf-8") as file:
        content = file.read()
    
    escaped_tokens = [re.escape(token) for token in special_tokens]
    
    joined_pattern = "|".join(escaped_tokens)

    re.split(joined_pattern, )

    

    

    

    print(content)



    PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
    re.findall(PAT, "some text that i'll pre-tokenize")

    #1) split

    #2) merge

    return 0

# %%
input_path = "/Users/jonyang/Desktop/git/learning/learning-CS336/assignment1-basics/cs336_basics/test_data/test.txt"
vocab_size = 300
special_tokens = ["<|endoftext|>"]
train_bpe()
# Out:
# low low low low low
# lower lower widest widest widest
# newest newest newest newest newest newest
# 0
